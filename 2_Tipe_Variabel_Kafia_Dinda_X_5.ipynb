# %% [markdown]
# <a href="https://colab.research.google.com/github/kafiazafira25/KKA-X-SEMESTER-1/blob/main/2_Tipe_Variabel_Kafia_Dinda_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Kafia Dinda Zafira
#
# Kelas : X-5
#
# No.absen : 18

# %% [markdown]
# Konsep Dasar Variabel

# %%
print("kafiadindaa@gmail.com")
print("kafiadindaa@gmail.com")
print("kafiadindaa@gmail.com")
# Out:
# kafiadindaa@gmail.com
# kafiadindaa@gmail.com
# kafiadindaa@gmail.com

# %%
email_user_1 = "kafiadindaa@gmail.com"
print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# kafiadindaa@gmail.com
# kafiadindaa@gmail.com
# kafiadindaa@gmail.com

# %% [markdown]
# Peraturan Penulisan Variabel

# %%
email user 2 = "kafiadindaa@gmail.com"
print(email user 2)
# Out:
#   File "/tmp/ipython-input-1074397834.py", line 1
#     email user 2 = "kafiadindaa@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
#Hanya boleh menggunakan angka, huruf
emailuser2 = "kafiadindaa@gmail.com"
print(emailuser2)
# Out:
# kafiadindaa@gmail.com

# %%
email_user_2 = "kafiadindaa@gmail.com"
print(email_user_2)
# Out:
# kafiadindaa@gmail.com

# %%
3_email_user = "kafiadindaa@gmail.com"
print(3_email_user)
# Out:
#   File "/tmp/ipython-input-292962812.py", line 1
#     3_email_user = "kafiadindaa@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Tidak boleh didahului oleh angka
email_user_3 = "kafiadindaa@gmail.com"
print(email_user_3)
# Out:
# kafiadindaa@gmail.com

# %%
email_user_4 = "kafiadindaa@gmail.com"
print(email_user_4)
# Out:
# kafiadindaa@gmail.com

# %%
#Penulisan variabel sensitif terhadap kapital
Email_User_4 = "KafiaDindaa@gmail.com"
print(Email_User_4)
# Out:
# KafiaDindaa@gmail.com

# %%
if = "kafia@gmail.com"
print(if)
# Out:
#   File "/tmp/ipython-input-1856819737.py", line 1
#     if = "kafia@gmail.com"
#        ^
# SyntaxError: invalid syntax

# %%
If = "kafia@gmail.com"
print(If)
# Out:
# kafia@gmail.com

# %%
print = "muhammadsyakoer@gmail.com"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-526786178.py in <cell line: 0>()
#       1 print = "muhammadsyakoer@gmail.com"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "muhammadsyakoer@gmail.com"

print(Print)
# Out:
# muhammadsyakoer@gmail.com

# %%
#Harus deskriptif meski tidak error
_ = "idhammultazam@Gmail.com"

print(_)
# Out:
# idhammultazam@Gmail.com

# %%
_ = "hanifmultazam@Gmail.com"

print(_)
# Out:
# hanifmultazam@Gmail.com

# %%
print(_)
# Out:
# hanifmultazam@Gmail.com

# %%
print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3925571382.py in <cell line: 0>()
# ----> 1 print(i)
#
# NameError: name 'i' is not defined

# %% [markdown]
# Assignment

# %%
#Siswa sudah saya kirimkan kode untuk di-re-create dan terdapat latihan soal

# %% [markdown]
# Aritmatika

# %%
#Siswa sudah saya kirimkan kode untuk di-re-create dan terdapat latihan soal

# %% [markdown]
# Jenis-jenis Operator aritmatika pada Python

# %%
#Penjumlahan
iphone_rolan = 21
iphone_gibran = 4

total_iphone = iphone_rolan + iphone_gibran

print(total_iphone)
# Out:
# 25

# %%
#Pengurangan
iphone_rolan = 21
iphone_gibran = 4

selisih_iphone = iphone_rolan - iphone_gibran

print(selisih_iphone)
# Out:
# 17

# %%
#perkalian
jumlah_dus = 5
jumlah_botol_per_dus = 10

total_botol = jumlah_dus * jumlah_botol_per_dus

print(total_botol)
# Out:
# 50

# %%
#Pembagian
iphone_rolan = 21
jumlah_anak_yatim = 5

pembagian_iphone = iphone_rolan / iphone_gibran

print(pembagian_iphone)
# Out:
# 5.25

# %%
#Pembagian bulat
iphone_rolan = 21
jumlah_anak_yatim = 5

pembagian_iphone = iphone_rolan // iphone_gibran

print(pembagian_iphone)
# Out:
# 5

# %%
#sisa bagi

iphone_rolan = 21
jumlah_anak_yatim = 5

sisa_bagi_iphone = iphone_rolan % jumlah_anak_yatim

print(sisa_bagi_iphone)
# Out:
# 1

# %%
#perpangkatan
sisi = 5

luas_persegi = sisi ** 2

print(luas_persegi)
# Out:
# 25

# %%
sisi = 2
volume_kubus = sisi ** 3

print(volume_kubus)
# Out:
# 8

# %%
luas_persegi = 25

sisi = luas_persegi ** (1/2)

print(sisi)
# Out:
# 5.0

# %%
volume_kubus = 8
sisi = volume_kubus ** (1/3)

print(sisi)
# Out:
# 2.0

# %% [markdown]
# Mengubah Tipe Data

# %%
a = 25
print(a)
type(a)
# Out:
# 25
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 25.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 25.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = True
print(b)
type(b)
# Out:
# True
# bool

# %%
b = int(b)
print(b)
type(b)
# Out:
# 1
# int

# %%
b = float(b)
print(b)
type(b)
# Out:
# 1.0
# float

# %%
b = str(b)
print(b)
type(b)
# Out:
# 1.0
# str

# %%
c = False
print(c)
type(c)
# Out:
# False
# bool

# %%
c = float(c)
print(c)
type(c)
# Out:
# 0.0
# float

# %%
c = int(c)
print(c)
type(c)
# Out:
# 0
# int

# %%
c = str(c)
print(c)
type(c)
# Out:
# 0
# str

# %% [markdown]
# Operator Perbandingan

# %%
print(6>0)
# Out:
# True

# %%
print(7>9)
# Out:
# False

# %%
print(8<9)
# Out:
# True

# %%
print(8<4)
# Out:
# False

# %%
print(5>=5)
# Out:
# True

# %%
print(6>=5)
# Out:
# True

# %%
print(3 == 2)
# Out:
# False

# %%
print(3 == 3)
# Out:
# True

# %%
print(5 != 5)
# Out:
# False

# %%
a = 8
b = 9
print(b<a)
# Out:
# False

# %%
print(b<8)
# Out:
# False

# %% [markdown]
# Operator Logika

# %%
print(7!=8 and 8>2)
# Out:
# True

# %%
print(7==8 and 8>2)
# Out:
# False

# %%
print(7==8 or 8>2)
# Out:
# True

# %%
print(not 7==8)
# Out:
# True

# %%
m = 10
n = 20
p = 30

print(m<n and p>m)
# Out:
# True

# %%
print(not (m<n or p>m))
# Out:
# False

# %% [markdown]
# Input

# %%
panjang = 5
lebar = 3

luas = panjang * lebar

print(luas)
# Out:
# 15

# %%
Panjang = int(input("Masukkan Panjang (cm): "))
Lebar = int(input("Masukkan Lebar (cm): "))

Luas = Panjang * Lebar

print(f"Luas persegi panjangnya yaitu {Luas} cm^2")
# Out:
# Masukkan Panjang (cm): 5
# Masukkan Lebar (cm): 4
# Luas persegi panjangnya yaitu 20 cm^2
