# %% [markdown]
# <a href="https://colab.research.google.com/github/kafiazafira25/KKA-X-SEMESTER-1/blob/main/3_App_bangun_balok_Kafia_Dinda_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama Kelompok : Kutu lompat
#
# Nama Lengkap : Kafia Dinda Zafira
#
# Kelas : X-5
#
# No. absen : 18

# %% [markdown]
# #App Bangun Balok

# %%
#Program menghitung volume balok

#Meminta input dari pengguna
panjang = float(input("Masukkan panjang balok (cm): "))
lebar = float(input("Masukkan lebar balok (cm): "))
tinggi = float(input("Masukkan tinggi balok (cm): "))

# Menghitung volume
volume = panjang * lebar * tinggi

# Menampilkan hasil
print(f"Volume balok adalah: {volume} cm^3.")
# Out:
# Masukkan panjang balok (cm): 5
# Masukkan lebar balok (cm): 3
# Masukkan tinggi balok (cm): 3
# Volume balok adalah: 45.0 cm^3.
