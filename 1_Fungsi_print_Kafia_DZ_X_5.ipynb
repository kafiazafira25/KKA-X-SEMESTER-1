# %% [markdown]
# <a href="https://colab.research.google.com/github/kafiazafira25/KKA-X-SEMESTER-1/blob/main/1_Fungsi_print_Kafia_DZ_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Menampilkan Teks Bebas

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print("Kafia Dinda Zafira")
# Out:
# Kafia Dinda Zafira

# %% [markdown]
# #2. Menampilkan Nilai Variabel

# %%
beratBadan = 87

print(beratBadan)
# Out:
# 87

# %%
tinggiBadan = 170

print(tinggiBadan)
# Out:
# 170

# %%
Nama = "Kafia Dinda Zafira"

print("Kafia Dinda Zafira")
# Out:
# Kafia Dinda Zafira

# %% [markdown]
# #3. Menampilkan Teks Bebas dan Nilai Variabel

# %%
print("Halo nama saya", Nama,". Berat badan saya",beratBadan,"Kg.")
# Out:
# Halo nama saya Kafia Dinda Zafira . Berat badan saya 87 Kg.

# %%
print("Halo nama saya "+ Nama+". Berat badan saya "+str(beratBadan)+" Kg.")
# Out:
# Halo nama saya Kafia Dinda Zafira. Berat badan saya 87 Kg.

# %%
print(f"Halo nama saya {Nama}. Berat badan saya {beratBadan} Kg.")
# Out:
# Halo nama saya Kafia Dinda Zafira. Berat badan saya 87 Kg.

# %% [markdown]
# #4.Escape Character

# %%
print("Nama: Kafia Dinda Zafira")
print("Kelas: X.5")
print("No. Absen: 18")
# Out:
# Nama: Kafia Dinda Zafira
# Kelas: X.5
# No. Absen: 18

# %%
print("Nama: Kafia Dinda Zafira\nKelas: X.5\nNo. Absen: 18")
# Out:
# Nama: Kafia Dinda Zafira
# Kelas: X.5
# No. Absen: 18

# %%
print("""Nama\t\t:Kafia Dinda Zafira
Kelas\t\t: X.5
No.Absen\t: 18""")
# Out:
# Nama		:Kafia Dinda Zafira
# Kelas		: X.5
# No.Absen	: 18

# %%
print('Nama saya Ja\'far Shodiq')
# Out:
# Nama saya Ja'far Shodiq

# %%
print("Nama saya Ja'far Shodiq")
# Out:
# Nama saya Ja'far Shodiq

# %%
print("Nama saya Ja\'far Shodiq")
# Out:
# Nama saya Ja'far Shodiq

# %%
print('Bu Shinta berkata, "Tolong perhatikan Tv dan saya."')
# Out:
# Bu Shinta berkata, "Tolong perhatikan Tv dan saya."

# %%
print("Bu Shinta berkata, \"Tolong perhatikan Tv dan saya.\"")
# Out:
# Bu Shinta berkata, "Tolong perhatikan Tv dan saya."

# %%
print ("Lokasi file tugas KKA adalah di local disk C:\\KKA\\Tugas")
# Out:
# Lokasi file tugas KKA adalah di local disk C:\KKA\Tugas

# %% [markdown]
# #Parameter Fungsi Print

# %%
nama_siswa_1 = "Jielo"
nama_siswa_2 = "Aida"
nama_siswa_3 = "Dani"
nama_siswa_4 = "Nurul"

print(nama_siswa_1, end="/")
print(nama_siswa_2, end="/")
print(nama_siswa_3, end="/")
print(nama_siswa_4)
# Out:
# Jielo/Aida/Dani/Nurul

# %%
nama_siswa_5 = "Hasbi"
nama_siswa_6 = "Habibi"
nama_siswa_7 = "Rendra"
nama_siswa_8 = "Naufal"

print(nama_siswa_8, nama_siswa_7, nama_siswa_6, nama_siswa_5, sep="*")
# Out:
# Naufal*Rendra*Habibi*Hasbi

# %%
nama_siswa_5 = "Hasbi"
nama_siswa_6 = "Habibi"
nama_siswa_7 = "Rendra"
nama_siswa_8 = "Naufal"

print(nama_siswa_8, nama_siswa_7, nama_siswa_5, nama_siswa_6, sep="-")
# Out:
# Naufal-Rendra-Hasbi-Habibi

# %%
print('''Bu Shinta berkata, "Berikut adalah daftar piket harian kelas X.5
yang disimpan di file D:\\MAN Demak\\Jadwal Piket.".''')
print("\nSenin\tSelasa\tRabu\nJielo\tHasbi\tNaufal\nAzzam\tAida\tA'inun")
# Out:
# Bu Shinta berkata, "Berikut adalah daftar piket harian kelas X.5
# yang disimpan di file D:\MAN Demak\Jadwal Piket.".
#
# Senin	Selasa	Rabu
# Jielo	Hasbi	Naufal
# Azzam	Aida	A'inun
